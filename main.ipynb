# %% [markdown]
# ## Installing Required Packages

# %%
# %pip install tensorflow matplotlib opencv-python mediapipe scikit-learn
# Out:
# Requirement already satisfied: tensorflow in ./test_env/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: matplotlib in ./test_env/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: opencv-python in ./test_env/lib/python3.10/site-packages (4.8.0.74)
# Requirement already satisfied: mediapipe in ./test_env/lib/python3.10/site-packages (0.10.2)
# Requirement already satisfied: scikit-learn in ./test_env/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./test_env/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in ./test_env/lib/python3.10/site-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: h5py>=2.9.0 in ./test_env/lib/python3.10/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./test_env/lib/python3.10/site-packages (from tensorflow) (1.56.2)
# Requirement already satisfied: keras<2.14,>=2.13.1 in ./test_env/lib/python3.10/site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: flatbuffers>=23.1.21 in ./test_env/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: packaging in ./test_env/lib/python3.10/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: wrapt>=1.11.0 in ./test_env/lib/python3.10/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in ./test_env/lib/python3.10/site-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./test_env/lib/python3.10/site-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./test_env/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: absl-py>=1.0.0 in ./test_env/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./test_env/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: libclang>=13.0.0 in ./test_env/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in ./test_env/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in ./test_env/lib/python3.10/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./test_env/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./test_env/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in ./test_env/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in ./test_env/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./test_env/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: cycler>=0.10 in ./test_env/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./test_env/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./test_env/lib/python3.10/site-packages (from matplotlib) (4.41.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./test_env/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in ./test_env/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./test_env/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in ./test_env/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: attrs>=19.1.0 in ./test_env/lib/python3.10/site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: sounddevice>=0.4.4 in ./test_env/lib/python3.10/site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: opencv-contrib-python in ./test_env/lib/python3.10/site-packages (from mediapipe) (4.8.0.74)
# Requirement already satisfied: joblib>=1.1.1 in ./test_env/lib/python3.10/site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: scipy>=1.5.0 in ./test_env/lib/python3.10/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./test_env/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./test_env/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.0)
# Requirement already satisfied: CFFI>=1.0 in ./test_env/lib/python3.10/site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./test_env/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in ./test_env/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./test_env/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.22.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./test_env/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./test_env/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: markdown>=2.6.8 in ./test_env/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.4)
# Requirement already satisfied: pycparser in ./test_env/lib/python3.10/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./test_env/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./test_env/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./test_env/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in ./test_env/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./test_env/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./test_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in ./test_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./test_env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./test_env/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./test_env/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./test_env/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
# Out:
# 2023-08-23 15:40:49.105459: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-23 15:40:49.944558: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Setting Up Media Pipe holistic Model to detect and draw keypoints (landmarks)

# %%
# MediaPipe Holistic will be used to detect key points
# and draw them on the cv2 feed
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                              mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1)
                              )
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(80, 22, 10), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(80, 44, 121), thickness=2, circle_radius=2)
                              )
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(121, 44, 250), thickness=2, circle_radius=2)
                              )
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                              mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                              )

# %%
def extract_keypoints(results):  
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# ### Generating and saving data for training and testing

# %%
DATA_PATH = os.path.join('MP_DATA')
actions = np.array(['hello', 'thanks', 'iloveyou'])
no_sequences = 30
sequence_length = 30  


# Making 3 folders to store 3 features, each has 30 samples (videos) with each sample containing 30 frames
# with all the landmarks concatenated into a np array

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# ### Capturing data using Open CV

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for action in actions:
        for sequence in range(no_sequences):
            for frame_num in range(sequence_length):
                # Reading frame from webcam (device -> 0)
                ret, frame = cap.read()
                # Make detections of Key Points
                image, results = mediapipe_detection(frame, holistic)
                # Drawing landmarks
                draw_landmarks(image, results)

                # Collecting videos frames
                # accounting for wait (delay)
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTION', (120, 200),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else:
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)

                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Exiting the loop 
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 cap.release()
#       2 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined

# %% [markdown]
# ### Labeling data with appropriate features

# %%
label_map = {label:num for num, label in enumerate(actions)}
print(label_map)
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(labels).shape
# Out:
# (90,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %% [markdown]
# ### Splitting data into training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
X_train.shape
# Out:
# (81, 30, 1662)

# %%
len(X_train)
# Out:
# 81

# %% [markdown]
# ## Building the Model

# %% [markdown]
# #### Setting Up TensorBoard (log file to be used by TB) to generate realtime logs and analytics on training

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# use tensorboard --logdir=. (from /Logs/train dir) on commandline

# %%
# %load_ext tensorboard

# %%
# %reload_ext tensorboard
# %tensorboard --logdir Logs/train
# Out:
#       <iframe id="tensorboard-frame-e7a8765161be3a16" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e7a8765161be3a16");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30, 1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# 2023-08-23 15:42:19.418768: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-23 15:42:19.486785: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 2023-08-23 15:42:30.429084: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 16154640 exceeds 10% of free system memory.
# 3/3 [==============================] - 3s 72ms/step - loss: 1.3372 - categorical_accuracy: 0.2469
# Epoch 2/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1762 - categorical_accuracy: 0.3704
# Epoch 3/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 3.2149 - categorical_accuracy: 0.3827
# Epoch 4/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 4.4645 - categorical_accuracy: 0.2716
# Epoch 5/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4834 - categorical_accuracy: 0.3086
# Epoch 6/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.2306 - categorical_accuracy: 0.2593
# Epoch 7/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.3320 - categorical_accuracy: 0.2963
# Epoch 8/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.7223 - categorical_accuracy: 0.2963
# Epoch 9/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1781 - categorical_accuracy: 0.3457
# Epoch 10/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 1.1926 - categorical_accuracy: 0.3333
# Epoch 11/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0926 - categorical_accuracy: 0.3333
# Epoch 12/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0573 - categorical_accuracy: 0.4198
# Epoch 13/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.2551 - categorical_accuracy: 0.3827
# Epoch 14/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0371 - categorical_accuracy: 0.4444
# Epoch 15/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0602 - categorical_accuracy: 0.5432
# Epoch 16/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1364 - categorical_accuracy: 0.3951
# Epoch 17/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0193 - categorical_accuracy: 0.5062
# Epoch 18/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0236 - categorical_accuracy: 0.4691
# Epoch 19/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9764 - categorical_accuracy: 0.5679
# Epoch 20/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.9209 - categorical_accuracy: 0.5926
# Epoch 21/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.9057 - categorical_accuracy: 0.5556
# Epoch 22/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.9061 - categorical_accuracy: 0.5432
# Epoch 23/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.8274 - categorical_accuracy: 0.5679
# Epoch 24/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.8286 - categorical_accuracy: 0.6420
# Epoch 25/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.8156 - categorical_accuracy: 0.6543
# Epoch 26/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.8949 - categorical_accuracy: 0.6667
# Epoch 27/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.9460 - categorical_accuracy: 0.4938
# Epoch 28/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.7470 - categorical_accuracy: 0.6667
# Epoch 29/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9375 - categorical_accuracy: 0.5185
# Epoch 30/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.7444 - categorical_accuracy: 0.6543
# Epoch 31/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.7405 - categorical_accuracy: 0.6420
# Epoch 32/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.6813 - categorical_accuracy: 0.7160
# Epoch 33/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.7179 - categorical_accuracy: 0.6790
# Epoch 34/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.7276 - categorical_accuracy: 0.6667
# Epoch 35/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.6084 - categorical_accuracy: 0.7284
# Epoch 36/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.5771 - categorical_accuracy: 0.7284
# Epoch 37/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5034 - categorical_accuracy: 0.7901
# Epoch 38/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.5499 - categorical_accuracy: 0.7531
# Epoch 39/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5448 - categorical_accuracy: 0.7160
# Epoch 40/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.7535 - categorical_accuracy: 0.7037
# Epoch 41/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.2825 - categorical_accuracy: 0.4321
# Epoch 42/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 0.7624 - categorical_accuracy: 0.6790
# Epoch 43/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.8877 - categorical_accuracy: 0.6543
# Epoch 44/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 0.9638 - categorical_accuracy: 0.4691
# Epoch 45/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.8736 - categorical_accuracy: 0.5926
# Epoch 46/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.8118 - categorical_accuracy: 0.6667
# Epoch 47/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.6989 - categorical_accuracy: 0.7160
# Epoch 48/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.7190 - categorical_accuracy: 0.6420
# Epoch 49/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.8234 - categorical_accuracy: 0.6420
# Epoch 50/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.7170 - categorical_accuracy: 0.6543
# Epoch 51/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.7428 - categorical_accuracy: 0.6667
# Epoch 52/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.6916 - categorical_accuracy: 0.7284
# Epoch 53/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.7583 - categorical_accuracy: 0.6790
# Epoch 54/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.6330 - categorical_accuracy: 0.7284
# Epoch 55/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.6457 - categorical_accuracy: 0.7531
# Epoch 56/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.6519 - categorical_accuracy: 0.7901
# Epoch 57/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.5053 - categorical_accuracy: 0.7407
# Epoch 58/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 0.5729 - categorical_accuracy: 0.7407
# Epoch 59/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.4826 - categorical_accuracy: 0.7654
# Epoch 60/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.5288 - categorical_accuracy: 0.7531
# Epoch 61/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5296 - categorical_accuracy: 0.8148
# Epoch 62/2000
# 3/3 [==============================] - 0s 80ms/step - loss: 0.5081 - categorical_accuracy: 0.7901
# Epoch 63/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.4603 - categorical_accuracy: 0.8148
# Epoch 64/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 0.5860 - categorical_accuracy: 0.7654
# Epoch 65/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.8861 - categorical_accuracy: 0.5185
# Epoch 66/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 0.7461 - categorical_accuracy: 0.6049
# Epoch 67/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5651 - categorical_accuracy: 0.7778
# Epoch 68/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.5050 - categorical_accuracy: 0.7284
# Epoch 69/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 0.6233 - categorical_accuracy: 0.6914
# Epoch 70/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.7560 - categorical_accuracy: 0.6173
# Epoch 71/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.5502 - categorical_accuracy: 0.7654
# Epoch 72/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4607 - categorical_accuracy: 0.7901
# Epoch 73/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4231 - categorical_accuracy: 0.7901
# Epoch 74/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.3821 - categorical_accuracy: 0.8272
# Epoch 75/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.4680 - categorical_accuracy: 0.7901
# Epoch 76/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3848 - categorical_accuracy: 0.8395
# Epoch 77/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3776 - categorical_accuracy: 0.8148
# Epoch 78/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4352 - categorical_accuracy: 0.8025
# Epoch 79/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3853 - categorical_accuracy: 0.8148
# Epoch 80/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.7025 - categorical_accuracy: 0.7037
# Epoch 81/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.7477 - categorical_accuracy: 0.6914
# Epoch 82/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.5794 - categorical_accuracy: 0.7284
# Epoch 83/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.5746 - categorical_accuracy: 0.7901
# Epoch 84/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.6617 - categorical_accuracy: 0.7901
# Epoch 85/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4709 - categorical_accuracy: 0.8395
# Epoch 86/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5125 - categorical_accuracy: 0.7654
# Epoch 87/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.5047 - categorical_accuracy: 0.7901
# Epoch 88/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4349 - categorical_accuracy: 0.8889
# Epoch 89/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.3610 - categorical_accuracy: 0.9136
# Epoch 90/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3266 - categorical_accuracy: 0.9012
# Epoch 91/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2907 - categorical_accuracy: 0.9383
# Epoch 92/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.2783 - categorical_accuracy: 0.8642
# Epoch 93/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2374 - categorical_accuracy: 0.8889
# Epoch 94/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.2886 - categorical_accuracy: 0.8765
# Epoch 95/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2445 - categorical_accuracy: 0.9012
# Epoch 96/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.4462 - categorical_accuracy: 0.8272
# Epoch 97/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3553 - categorical_accuracy: 0.8272
# Epoch 98/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.2918 - categorical_accuracy: 0.8765
# Epoch 99/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.4201 - categorical_accuracy: 0.8148
# Epoch 100/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.5460 - categorical_accuracy: 0.7531
# Epoch 101/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.5519 - categorical_accuracy: 0.7407
# Epoch 102/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.3180 - categorical_accuracy: 0.8519
# Epoch 103/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.3780 - categorical_accuracy: 0.7901
# Epoch 104/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3231 - categorical_accuracy: 0.8889
# Epoch 105/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3744 - categorical_accuracy: 0.8395
# Epoch 106/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3125 - categorical_accuracy: 0.9136
# Epoch 107/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2980 - categorical_accuracy: 0.8519
# Epoch 108/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2002 - categorical_accuracy: 0.9506
# Epoch 109/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.2380 - categorical_accuracy: 0.9136
# Epoch 110/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2916 - categorical_accuracy: 0.8889
# Epoch 111/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2583 - categorical_accuracy: 0.8642
# Epoch 112/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3241 - categorical_accuracy: 0.8642
# Epoch 113/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4553 - categorical_accuracy: 0.7654
# Epoch 114/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3329 - categorical_accuracy: 0.9012
# Epoch 115/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4191 - categorical_accuracy: 0.8395
# Epoch 116/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2555 - categorical_accuracy: 0.8765
# Epoch 117/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.2094 - categorical_accuracy: 0.9259
# Epoch 118/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.2331 - categorical_accuracy: 0.8889
# Epoch 119/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.1332 - categorical_accuracy: 0.9753
# Epoch 120/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2292 - categorical_accuracy: 0.8889
# Epoch 121/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1385 - categorical_accuracy: 0.9383
# Epoch 122/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1020 - categorical_accuracy: 0.9630
# Epoch 123/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1306 - categorical_accuracy: 0.9506
# Epoch 124/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0875 - categorical_accuracy: 0.9753
# Epoch 125/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0932 - categorical_accuracy: 0.9630
# Epoch 126/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0577 - categorical_accuracy: 0.9877
# Epoch 127/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0718 - categorical_accuracy: 0.9630
# Epoch 128/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0774 - categorical_accuracy: 0.9630
# Epoch 129/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0691 - categorical_accuracy: 0.9877
# Epoch 130/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1834 - categorical_accuracy: 0.9630
# Epoch 131/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.7192 - categorical_accuracy: 0.8272
# Epoch 132/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.7125 - categorical_accuracy: 0.7407
# Epoch 133/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.0536 - categorical_accuracy: 0.8272
# Epoch 134/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.3888 - categorical_accuracy: 0.4815
# Epoch 135/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.0742 - categorical_accuracy: 0.5309
# Epoch 136/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.9472 - categorical_accuracy: 0.5062
# Epoch 137/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.8733 - categorical_accuracy: 0.5062
# Epoch 138/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.7862 - categorical_accuracy: 0.5432
# Epoch 139/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 0.7059 - categorical_accuracy: 0.5802
# Epoch 140/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.6478 - categorical_accuracy: 0.6420
# Epoch 141/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5759 - categorical_accuracy: 0.7037
# Epoch 142/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5355 - categorical_accuracy: 0.8025
# Epoch 143/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.4398 - categorical_accuracy: 0.8889
# Epoch 144/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3659 - categorical_accuracy: 0.8519
# Epoch 145/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.4343 - categorical_accuracy: 0.8395
# Epoch 146/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.9450 - categorical_accuracy: 0.6790
# Epoch 147/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.7251 - categorical_accuracy: 0.7037
# Epoch 148/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0515 - categorical_accuracy: 0.4938
# Epoch 149/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.9737 - categorical_accuracy: 0.5432
# Epoch 150/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.8372 - categorical_accuracy: 0.4568
# Epoch 151/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.7035 - categorical_accuracy: 0.6420
# Epoch 152/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5911 - categorical_accuracy: 0.7037
# Epoch 153/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.6573 - categorical_accuracy: 0.6790
# Epoch 154/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.3237 - categorical_accuracy: 0.2840
# Epoch 155/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.8101 - categorical_accuracy: 0.6790
# Epoch 156/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9203 - categorical_accuracy: 0.5185
# Epoch 157/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.9010 - categorical_accuracy: 0.5185
# Epoch 158/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.7717 - categorical_accuracy: 0.7901
# Epoch 159/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.5711 - categorical_accuracy: 0.8025
# Epoch 160/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.8218 - categorical_accuracy: 0.6790
# Epoch 161/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.8785 - categorical_accuracy: 0.5679
# Epoch 162/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.6588 - categorical_accuracy: 0.7531
# Epoch 163/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.5557 - categorical_accuracy: 0.8272
# Epoch 164/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.5661 - categorical_accuracy: 0.7407
# Epoch 165/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.5562 - categorical_accuracy: 0.7284
# Epoch 166/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.4694 - categorical_accuracy: 0.8148
# Epoch 167/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.4259 - categorical_accuracy: 0.8395
# Epoch 168/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.3775 - categorical_accuracy: 0.8642
# Epoch 169/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.3290 - categorical_accuracy: 0.8519
# Epoch 170/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4095 - categorical_accuracy: 0.8025
# Epoch 171/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.5027 - categorical_accuracy: 0.8519
# Epoch 172/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 2.5693 - categorical_accuracy: 0.4568
# Epoch 173/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.5244 - categorical_accuracy: 0.3210
# Epoch 174/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.2539 - categorical_accuracy: 0.2593
# Epoch 175/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0150 - categorical_accuracy: 0.5556
# Epoch 176/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0429 - categorical_accuracy: 0.5556
# Epoch 177/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.0411 - categorical_accuracy: 0.5432
# Epoch 178/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.0461 - categorical_accuracy: 0.3827
# Epoch 179/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.0142 - categorical_accuracy: 0.5185
# Epoch 180/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9462 - categorical_accuracy: 0.6296
# Epoch 181/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.9781 - categorical_accuracy: 0.5309
# Epoch 182/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.1247 - categorical_accuracy: 0.3580
# Epoch 183/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1274 - categorical_accuracy: 0.3333
# Epoch 184/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1126 - categorical_accuracy: 0.3086
# Epoch 185/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0842 - categorical_accuracy: 0.3333
# Epoch 186/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.1539 - categorical_accuracy: 0.3333
# Epoch 187/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0931 - categorical_accuracy: 0.3086
# Epoch 188/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0988 - categorical_accuracy: 0.2963
# Epoch 189/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.1861 - categorical_accuracy: 0.2099
# Epoch 190/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.4628 - categorical_accuracy: 0.2963
# Epoch 191/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.3756 - categorical_accuracy: 0.3457
# Epoch 192/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 1.1327 - categorical_accuracy: 0.2716
# Epoch 193/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 1.1804 - categorical_accuracy: 0.3333
# Epoch 194/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 1.1068 - categorical_accuracy: 0.3333
# Epoch 195/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.0992 - categorical_accuracy: 0.3333
# Epoch 196/2000
# 3/3 [==============================] - 0s 79ms/step - loss: 1.0940 - categorical_accuracy: 0.2840
# Epoch 197/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 1.0896 - categorical_accuracy: 0.3210
# Epoch 198/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 1.0875 - categorical_accuracy: 0.3210
# Epoch 199/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.0827 - categorical_accuracy: 0.3457
# Epoch 200/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 1.0791 - categorical_accuracy: 0.3333
# Epoch 201/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0750 - categorical_accuracy: 0.3086
# Epoch 202/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0692 - categorical_accuracy: 0.3086
# Epoch 203/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0647 - categorical_accuracy: 0.2963
# Epoch 204/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0537 - categorical_accuracy: 0.3333
# Epoch 205/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.0411 - categorical_accuracy: 0.4198
# Epoch 206/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0242 - categorical_accuracy: 0.4691
# Epoch 207/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 1.0138 - categorical_accuracy: 0.4198
# Epoch 208/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9691 - categorical_accuracy: 0.5432
# Epoch 209/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9939 - categorical_accuracy: 0.4568
# Epoch 210/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.9592 - categorical_accuracy: 0.5185
# Epoch 211/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 0.9121 - categorical_accuracy: 0.5185
# Epoch 212/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.8082 - categorical_accuracy: 0.6296
# Epoch 213/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.7525 - categorical_accuracy: 0.5802
# Epoch 214/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.1443 - categorical_accuracy: 0.4691
# Epoch 215/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.9107 - categorical_accuracy: 0.5185
# Epoch 216/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0525 - categorical_accuracy: 0.3210
# Epoch 217/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.0403 - categorical_accuracy: 0.5062
# Epoch 218/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0064 - categorical_accuracy: 0.5679
# Epoch 219/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9821 - categorical_accuracy: 0.4815
# Epoch 220/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9386 - categorical_accuracy: 0.5679
# Epoch 221/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.8940 - categorical_accuracy: 0.5062
# Epoch 222/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.8977 - categorical_accuracy: 0.5185
# Epoch 223/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.9603 - categorical_accuracy: 0.4198
# Epoch 224/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.8967 - categorical_accuracy: 0.5309
# Epoch 225/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.8467 - categorical_accuracy: 0.5926
# Epoch 226/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.7137 - categorical_accuracy: 0.6049
# Epoch 227/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.6744 - categorical_accuracy: 0.7407
# Epoch 228/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0581 - categorical_accuracy: 0.6296
# Epoch 229/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.6543 - categorical_accuracy: 0.6543
# Epoch 230/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.7293 - categorical_accuracy: 0.6914
# Epoch 231/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.7082 - categorical_accuracy: 0.6173
# Epoch 232/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.5944 - categorical_accuracy: 0.7284
# Epoch 233/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5346 - categorical_accuracy: 0.7284
# Epoch 234/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.5419 - categorical_accuracy: 0.7778
# Epoch 235/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.5329 - categorical_accuracy: 0.7901
# Epoch 236/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 0.4821 - categorical_accuracy: 0.8395
# Epoch 237/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.4793 - categorical_accuracy: 0.7778
# Epoch 238/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.6764 - categorical_accuracy: 0.7407
# Epoch 239/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.4895 - categorical_accuracy: 0.7901
# Epoch 240/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5007 - categorical_accuracy: 0.7901
# Epoch 241/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4170 - categorical_accuracy: 0.8148
# Epoch 242/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3739 - categorical_accuracy: 0.8519
# Epoch 243/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.6255 - categorical_accuracy: 0.7407
# Epoch 244/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.3886 - categorical_accuracy: 0.8519
# Epoch 245/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.6759 - categorical_accuracy: 0.7037
# Epoch 246/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.7538 - categorical_accuracy: 0.5926
# Epoch 247/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.4901 - categorical_accuracy: 0.8148
# Epoch 248/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.5497 - categorical_accuracy: 0.7284
# Epoch 249/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.4356 - categorical_accuracy: 0.8519
# Epoch 250/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.5128 - categorical_accuracy: 0.7407
# Epoch 251/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3754 - categorical_accuracy: 0.8642
# Epoch 252/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3835 - categorical_accuracy: 0.8148
# Epoch 253/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3835 - categorical_accuracy: 0.8889
# Epoch 254/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3862 - categorical_accuracy: 0.8395
# Epoch 255/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 0.4411 - categorical_accuracy: 0.8148
# Epoch 256/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.4650 - categorical_accuracy: 0.8148
# Epoch 257/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3431 - categorical_accuracy: 0.8642
# Epoch 258/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.3448 - categorical_accuracy: 0.8642
# Epoch 259/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.4042 - categorical_accuracy: 0.8025
# Epoch 260/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.2999 - categorical_accuracy: 0.8889
# Epoch 261/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2279 - categorical_accuracy: 0.9630
# Epoch 262/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1900 - categorical_accuracy: 0.9383
# Epoch 263/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2022 - categorical_accuracy: 0.9012
# Epoch 264/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1822 - categorical_accuracy: 0.9506
# Epoch 265/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1699 - categorical_accuracy: 0.9630
# Epoch 266/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1767 - categorical_accuracy: 0.9136
# Epoch 267/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.1883 - categorical_accuracy: 0.9259
# Epoch 268/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.2490 - categorical_accuracy: 0.8765
# Epoch 269/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2101 - categorical_accuracy: 0.9136
# Epoch 270/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1763 - categorical_accuracy: 0.9259
# Epoch 271/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2236 - categorical_accuracy: 0.8889
# Epoch 272/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2034 - categorical_accuracy: 0.9259
# Epoch 273/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2424 - categorical_accuracy: 0.8889
# Epoch 274/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.1705 - categorical_accuracy: 0.9259
# Epoch 275/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.1137 - categorical_accuracy: 0.9630
# Epoch 276/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1422 - categorical_accuracy: 0.9383
# Epoch 277/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1098 - categorical_accuracy: 0.9753
# Epoch 278/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1230 - categorical_accuracy: 0.9383
# Epoch 279/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0796 - categorical_accuracy: 0.9877
# Epoch 280/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1041 - categorical_accuracy: 0.9630
# Epoch 281/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1098 - categorical_accuracy: 0.9383
# Epoch 282/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.2963 - categorical_accuracy: 0.8889
# Epoch 283/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0938 - categorical_accuracy: 0.9877
# Epoch 284/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1786 - categorical_accuracy: 0.9259
# Epoch 285/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.2110 - categorical_accuracy: 0.9012
# Epoch 286/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.3036 - categorical_accuracy: 0.9136
# Epoch 287/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1836 - categorical_accuracy: 0.9136
# Epoch 288/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1404 - categorical_accuracy: 0.9383
# Epoch 289/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0920 - categorical_accuracy: 0.9506
# Epoch 290/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0750 - categorical_accuracy: 0.9753
# Epoch 291/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0564 - categorical_accuracy: 0.9877
# Epoch 292/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0697 - categorical_accuracy: 0.9753
# Epoch 293/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0855 - categorical_accuracy: 0.9506
# Epoch 294/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1493 - categorical_accuracy: 0.9136
# Epoch 295/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0565 - categorical_accuracy: 0.9753
# Epoch 296/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0580 - categorical_accuracy: 0.9753
# Epoch 297/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0679 - categorical_accuracy: 0.9753
# Epoch 298/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0463 - categorical_accuracy: 0.9753
# Epoch 299/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0464 - categorical_accuracy: 1.0000
# Epoch 300/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0615 - categorical_accuracy: 0.9506
# Epoch 301/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0289 - categorical_accuracy: 1.0000
# Epoch 302/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0151 - categorical_accuracy: 1.0000
# Epoch 303/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0253 - categorical_accuracy: 1.0000
# Epoch 304/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0522 - categorical_accuracy: 0.9877
# Epoch 305/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0133 - categorical_accuracy: 1.0000
# Epoch 306/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0527 - categorical_accuracy: 0.9753
# Epoch 307/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.3831 - categorical_accuracy: 0.8519
# Epoch 308/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0856 - categorical_accuracy: 0.9506
# Epoch 309/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.2519 - categorical_accuracy: 0.8889
# Epoch 310/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.1504 - categorical_accuracy: 0.9259
# Epoch 311/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0547 - categorical_accuracy: 0.9877
# Epoch 312/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0323 - categorical_accuracy: 1.0000
# Epoch 313/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0449 - categorical_accuracy: 0.9877
# Epoch 314/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0433 - categorical_accuracy: 0.9877
# Epoch 315/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0307 - categorical_accuracy: 1.0000
# Epoch 316/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0333 - categorical_accuracy: 1.0000
# Epoch 317/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0290 - categorical_accuracy: 1.0000
# Epoch 318/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0243 - categorical_accuracy: 1.0000
# Epoch 319/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0159 - categorical_accuracy: 1.0000
# Epoch 320/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0168 - categorical_accuracy: 1.0000
# Epoch 321/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0081 - categorical_accuracy: 1.0000
# Epoch 322/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0075 - categorical_accuracy: 1.0000
# Epoch 323/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0046 - categorical_accuracy: 1.0000
# Epoch 324/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0037 - categorical_accuracy: 1.0000
# Epoch 325/2000
# 3/3 [==============================] - 0s 58ms/step - loss: 0.0030 - categorical_accuracy: 1.0000
# Epoch 326/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 0.0024 - categorical_accuracy: 1.0000
# Epoch 327/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 328/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 329/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 330/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 331/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 332/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 333/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 334/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0011 - categorical_accuracy: 1.0000
# Epoch 335/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 0.0010 - categorical_accuracy: 1.0000
# Epoch 336/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 9.7769e-04 - categorical_accuracy: 1.0000
# Epoch 337/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 8.9154e-04 - categorical_accuracy: 1.0000
# Epoch 338/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 7.7223e-04 - categorical_accuracy: 1.0000
# Epoch 339/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 7.0060e-04 - categorical_accuracy: 1.0000
# Epoch 340/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 6.6162e-04 - categorical_accuracy: 1.0000
# Epoch 341/2000
# 3/3 [==============================] - 0s 74ms/step - loss: 6.2014e-04 - categorical_accuracy: 1.0000
# Epoch 342/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 5.9086e-04 - categorical_accuracy: 1.0000
# Epoch 343/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 5.5301e-04 - categorical_accuracy: 1.0000
# Epoch 344/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 5.1352e-04 - categorical_accuracy: 1.0000
# Epoch 345/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 4.8284e-04 - categorical_accuracy: 1.0000
# Epoch 346/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 4.5135e-04 - categorical_accuracy: 1.0000
# Epoch 347/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 4.3386e-04 - categorical_accuracy: 1.0000
# Epoch 348/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 4.0655e-04 - categorical_accuracy: 1.0000
# Epoch 349/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 3.9200e-04 - categorical_accuracy: 1.0000
# Epoch 350/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 3.7608e-04 - categorical_accuracy: 1.0000
# Epoch 351/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.5134e-04 - categorical_accuracy: 1.0000
# Epoch 352/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 3.4569e-04 - categorical_accuracy: 1.0000
# Epoch 353/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 3.2334e-04 - categorical_accuracy: 1.0000
# Epoch 354/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 3.0907e-04 - categorical_accuracy: 1.0000
# Epoch 355/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.9280e-04 - categorical_accuracy: 1.0000
# Epoch 356/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 2.7874e-04 - categorical_accuracy: 1.0000
# Epoch 357/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 2.7166e-04 - categorical_accuracy: 1.0000
# Epoch 358/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 2.6135e-04 - categorical_accuracy: 1.0000
# Epoch 359/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.4918e-04 - categorical_accuracy: 1.0000
# Epoch 360/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.4050e-04 - categorical_accuracy: 1.0000
# Epoch 361/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 2.3167e-04 - categorical_accuracy: 1.0000
# Epoch 362/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.2227e-04 - categorical_accuracy: 1.0000
# Epoch 363/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 2.1501e-04 - categorical_accuracy: 1.0000
# Epoch 364/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.0533e-04 - categorical_accuracy: 1.0000
# Epoch 365/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 2.0001e-04 - categorical_accuracy: 1.0000
# Epoch 366/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.9098e-04 - categorical_accuracy: 1.0000
# Epoch 367/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.8531e-04 - categorical_accuracy: 1.0000
# Epoch 368/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.7846e-04 - categorical_accuracy: 1.0000
# Epoch 369/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.7365e-04 - categorical_accuracy: 1.0000
# Epoch 370/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.6758e-04 - categorical_accuracy: 1.0000
# Epoch 371/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.5860e-04 - categorical_accuracy: 1.0000
# Epoch 372/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.5440e-04 - categorical_accuracy: 1.0000
# Epoch 373/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4895e-04 - categorical_accuracy: 1.0000
# Epoch 374/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.4290e-04 - categorical_accuracy: 1.0000
# Epoch 375/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.3839e-04 - categorical_accuracy: 1.0000
# Epoch 376/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.3274e-04 - categorical_accuracy: 1.0000
# Epoch 377/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.2814e-04 - categorical_accuracy: 1.0000
# Epoch 378/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.2222e-04 - categorical_accuracy: 1.0000
# Epoch 379/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1757e-04 - categorical_accuracy: 1.0000
# Epoch 380/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.1268e-04 - categorical_accuracy: 1.0000
# Epoch 381/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 1.0759e-04 - categorical_accuracy: 1.0000
# Epoch 382/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.0265e-04 - categorical_accuracy: 1.0000
# Epoch 383/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 9.7539e-05 - categorical_accuracy: 1.0000
# Epoch 384/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 9.2471e-05 - categorical_accuracy: 1.0000
# Epoch 385/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 8.5872e-05 - categorical_accuracy: 1.0000
# Epoch 386/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 7.8276e-05 - categorical_accuracy: 1.0000
# Epoch 387/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 7.0626e-05 - categorical_accuracy: 1.0000
# Epoch 388/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 6.2422e-05 - categorical_accuracy: 1.0000
# Epoch 389/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 5.4345e-05 - categorical_accuracy: 1.0000
# Epoch 390/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 4.4222e-05 - categorical_accuracy: 1.0000
# Epoch 391/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 3.8028e-05 - categorical_accuracy: 1.0000
# Epoch 392/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 3.3171e-05 - categorical_accuracy: 1.0000
# Epoch 393/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 2.9117e-05 - categorical_accuracy: 1.0000
# Epoch 394/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 2.6292e-05 - categorical_accuracy: 1.0000
# Epoch 395/2000
# 3/3 [==============================] - 0s 59ms/step - loss: 2.4119e-05 - categorical_accuracy: 1.0000
# Epoch 396/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 2.1926e-05 - categorical_accuracy: 1.0000
# Epoch 397/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 2.0952e-05 - categorical_accuracy: 1.0000
# Epoch 398/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 1.9962e-05 - categorical_accuracy: 1.0000
# Epoch 399/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.9725e-05 - categorical_accuracy: 1.0000
# Epoch 400/2000
# 3/3 [==============================] - 0s 61ms/step - loss: 1.8384e-05 - categorical_accuracy: 1.0000
# Epoch 401/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.7285e-05 - categorical_accuracy: 1.0000
# Epoch 402/2000
# 3/3 [==============================] - 0s 60ms/step - loss: 1.7156e-05 - categorical_accuracy: 1.0000
# Epoch 403/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.6873e-05 - categorical_accuracy: 1.0000
# Epoch 404/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.6501e-05 - categorical_accuracy: 1.0000
# Epoch 405/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.6127e-05 - categorical_accuracy: 1.0000
# Epoch 406/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 1.5608e-05 - categorical_accuracy: 1.0000
# Epoch 407/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.5240e-05 - categorical_accuracy: 1.0000
# Epoch 408/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.4884e-05 - categorical_accuracy: 1.0000
# Epoch 409/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.4676e-05 - categorical_accuracy: 1.0000
# Epoch 410/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.4469e-05 - categorical_accuracy: 1.0000
# Epoch 411/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.4093e-05 - categorical_accuracy: 1.0000
# Epoch 412/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.3887e-05 - categorical_accuracy: 1.0000
# Epoch 413/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.3584e-05 - categorical_accuracy: 1.0000
# Epoch 414/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.3303e-05 - categorical_accuracy: 1.0000
# Epoch 415/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.3186e-05 - categorical_accuracy: 1.0000
# Epoch 416/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.2955e-05 - categorical_accuracy: 1.0000
# Epoch 417/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.2622e-05 - categorical_accuracy: 1.0000
# Epoch 418/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.2357e-05 - categorical_accuracy: 1.0000
# Epoch 419/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 1.2144e-05 - categorical_accuracy: 1.0000
# Epoch 420/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 1.1973e-05 - categorical_accuracy: 1.0000
# Epoch 421/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.1742e-05 - categorical_accuracy: 1.0000
# Epoch 422/2000
# ...
# Epoch 1866/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1867/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1868/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1869/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1870/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1871/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1872/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1873/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1874/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1875/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1876/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1877/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1878/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1879/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.1774e-08 - categorical_accuracy: 1.0000
# Epoch 1880/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1881/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1882/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1883/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1884/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1885/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1886/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1887/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1888/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1889/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1890/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1891/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1892/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1893/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1894/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1895/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1896/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1897/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1898/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1899/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1900/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1901/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1902/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1903/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1904/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1905/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1906/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1907/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1908/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1909/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1910/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1911/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1912/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1913/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1914/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1915/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1916/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1917/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1918/2000
# 3/3 [==============================] - 0s 77ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1919/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1920/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1921/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1922/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1923/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1924/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1925/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1926/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1927/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1928/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1929/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1930/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1931/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1932/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1933/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1934/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1935/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1936/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1937/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1938/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1939/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1940/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1941/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1942/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1943/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1944/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1945/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1946/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1947/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1948/2000
# 3/3 [==============================] - 0s 71ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1949/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1950/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1951/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1952/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1953/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1954/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1955/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1956/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1957/2000
# 3/3 [==============================] - 0s 72ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1958/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1959/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1960/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1961/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1962/2000
# 3/3 [==============================] - 0s 76ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1963/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1964/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1965/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1966/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1967/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1968/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1969/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1970/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1971/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1972/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1973/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1974/2000
# 3/3 [==============================] - 0s 70ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1975/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1976/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1977/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1978/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1979/2000
# 3/3 [==============================] - 0s 75ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1980/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1981/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1982/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1983/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1984/2000
# 3/3 [==============================] - 0s 78ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1985/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1986/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1987/2000
# 3/3 [==============================] - 0s 73ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1988/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1989/2000
# 3/3 [==============================] - 0s 64ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1990/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1991/2000
# 3/3 [==============================] - 0s 68ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1992/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1993/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 1.0302e-08 - categorical_accuracy: 1.0000
# Epoch 1994/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1995/2000
# 3/3 [==============================] - 0s 67ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1996/2000
# 3/3 [==============================] - 0s 69ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1997/2000
# 3/3 [==============================] - 0s 66ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1998/2000
# 3/3 [==============================] - 0s 62ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 1999/2000
# 3/3 [==============================] - 0s 65ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000
# Epoch 2000/2000
# 3/3 [==============================] - 0s 63ms/step - loss: 8.8303e-09 - categorical_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596675 (2.28 MB)
# Trainable params: 596675 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Saving weights
model.save('action.h5')
# to reload weights
# model.load_weights('action.h5)
# Out:
# /home/aryan/Desktop/test/test_env/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.save('action.keras')

# %% [markdown]
# ### Making Predictions and Evaluating the model

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 277ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[4, 1],
#         [0, 4]],
#
#        [[5, 1],
#         [1, 2]],
#
#        [[7, 0],
#         [1, 1]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.7777777777777778

# %%
# function to render (visualize) probability rectangles dynamically on prediction frames
colors = [(245,117,16), (117,245,16), (16,117,245)]
def probability_visualization(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0, 60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    return output_frame

# %% [markdown]
# ### Making real time predictions

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.7

cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        # Reading frame from webcam (0)
        ret, frame = cap.read()
        # Make detections of Key Points
        image, results = mediapipe_detection(frame, holistic)
        # Drawing landmarks
        draw_landmarks(image, results)

        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            predictions.append(np.argmax(res))

            if np.unique(predictions[-10:])[0] == np.argmax(res):
                if res[np.argmax(res)] > threshold:
                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5:
                sentence = sentence[-5:]
            
            image = probability_visualization(res, actions, image, colors)

        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ''.join(sentence), (3, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Displaying the captured frame (image)
        cv2.imshow('OpenCV Feed', image)
        # Exiting the loop 
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
